# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot([3,4,6],[8,10,14])
plt.show()

# %%
x =[3,4,6]
y=[8,10,14]
plt.plot(x,y)
plt.show()

# %%
# %matplotlib inline
x =[3,4,6]
y=[8,10,14]
plt.plot(x,y)
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Income by Age ')
plt.show()

# %%
# %matplotlib inline
x =[3,4,6]
y=[8,10,14]
plt.bar(x,y)
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Income by Age ')
plt.show()

# %%
income = [5,13,23,33,43,48,54,56,64,68,73,40,30,23]
# bins = [0,10,20,30,40,50,60,70]
bins = [0,5,10,15,20,25,30]
plt.hist(income)
plt.title('Income Distribution')

# %%
mktg = pd.read_csv('D:/dat1/retailMarketing2.csv',sep=',')
mktg.head()
# Out:
#       Age  Gender OwnHome  Married Location  Salary  Children History  \
# 0     Old  Female     Own   Single      Far   47500         0    High
# 1  Middle    Male    Rent   Single    Close   63600         0    High
# 2   Young  Female    Rent   Single    Close   13500         0     Low
# 3  Middle    Male     Own  Married    Close   85600         1    High
# 4  Middle  Female     Own   Single    Close   68400         0    High
#
#    Catalogs  AmountSpent
# 0         6          755
# 1         6         1318
# 2        18          296
# 3        18         2436
# 4        12         1304

# %%
mktg.shape
mktg.columns
# Out:
# Index([u'Age', u'Gender', u'OwnHome', u'Married', u'Location', u'Salary',
#        u'Children', u'History', u'Catalogs', u'AmountSpent'],
#       dtype='object')

# %%
mktg.describe()
# Out:
#               Salary    Children     Catalogs  AmountSpent
# count    1000.000000  1000.00000  1000.000000  1000.000000
# mean    56103.900000     0.93400    14.682000  1216.770000
# std     30616.314826     1.05107     6.622895   961.068613
# min     10100.000000     0.00000     6.000000    38.000000
# 25%     29975.000000     0.00000     6.000000   488.250000
# 50%     53700.000000     1.00000    12.000000   962.000000
# 75%     77025.000000     2.00000    18.000000  1688.500000
# max    168800.000000     3.00000    24.000000  6217.000000

# %%
# histograms are bin biased
plt.hist(mktg['AmountSpent'],bins=10)
# Out:
# (array([ 356.,  261.,  181.,   95.,   65.,   24.,    8.,    2.,    5.,    3.]),
#  array([   38. ,   655.9,  1273.8,  1891.7,  2509.6,  3127.5,  3745.4,
#          4363.3,  4981.2,  5599.1,  6217. ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(mktg['AmountSpent'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xe940128>],
#  'caps': [<matplotlib.lines.Line2D at 0xe940e10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xe94eeb8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xe94e940>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xe940278>,
#   <matplotlib.lines.Line2D at 0xe940898>]}

# %%
sns.boxplot(mktg['OwnHome'],mktg['Salary'])
plt.show()

# %%
mktg.head()
# Out:
#       Age  Gender OwnHome  Married Location  Salary  Children History  \
# 0     Old  Female     Own   Single      Far   47500         0    High
# 1  Middle    Male    Rent   Single    Close   63600         0    High
# 2   Young  Female    Rent   Single    Close   13500         0     Low
# 3  Middle    Male     Own  Married    Close   85600         1    High
# 4  Middle  Female     Own   Single    Close   68400         0    High
#
#    Catalogs  AmountSpent
# 0         6          755
# 1         6         1318
# 2        18          296
# 3        18         2436
# 4        12         1304

# %%
sns.stripplot(mktg['OwnHome'],mktg['Salary'])

# %%
sns.stripplot(mktg['OwnHome'],mktg['Salary'],jitter=True)

# %%
sns.stripplot(mktg['OwnHome'],mktg['Salary'],hue=mktg.Gender,jitter=True)

# %%
sns.swarmplot(mktg['OwnHome'],mktg['Salary'],hue=mktg.Gender)

# %% [markdown]
# ** Insights **
# Those own the house , especially, majority of the males salary is 100000
