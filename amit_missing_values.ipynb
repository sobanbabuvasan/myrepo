# %%
import numpy as np
import pandas as pd
from scipy.stats import mode

# %%
retail = pd.read_csv('D:/dat1/retailMissing.csv',sep=',')
retail.head(2)
# Out:
#                                         Product Name                Category  \
# 0   Eldon Base for stackable storage shelf, platinum  Storage & Organization
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...              Appliances
#
#          storeManager  quantity  Price  PercentageSold
# 0  Muhammed MacIntyre       3.0  35.00            0.80
# 1        Barry French     293.0  68.02            0.58

# %%
retail.isnull().sum()
# Out:
# Product Name       3
# Category           9
# storeManager       2
# quantity          27
# Price              7
# PercentageSold    15
# dtype: int64

# %%
retail.shape
# Out:
# (100, 6)

# %%
retail.notnull().sum()
# Out:
# Product Name      97
# Category          91
# storeManager      98
# quantity          73
# Price             93
# PercentageSold    85
# dtype: int64

# %%
print retail['quantity'].isnull().sum()
# Out:
# 27

# %%
print np.nanmean(retail['quantity'])
# Out:
# 5126.01369863

# %%
retail['quantity'].fillna(np.mean(retail['quantity']),inplace=True)

# %%
print retail['quantity'].isnull().sum()
# Out:
# 0

# %%
retail.dtypes
# Out:
# Product Name       object
# Category           object
# storeManager       object
# quantity          float64
# Price             float64
# PercentageSold    float64
# dtype: object

# %%
retail['storeManager'].fillna(mode(retail['storeManager'],nan_policy='omit').mode[0],inplace=True)

# %%
retail['storeManager'].isnull().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
retail['Price'].hist()
plt.show()

# %%
retail.isnull().sum()
# Out:
# Product Name       3
# Category           9
# storeManager       2
# quantity          27
# Price              7
# PercentageSold    15
# dtype: int64

# %%
retail.dropna(how='any',inplace=True)

# %%
retail.isnull().sum()
# Out:
# Product Name      0
# Category          0
# storeManager      0
# quantity          0
# Price             0
# PercentageSold    0
# dtype: int64

# %%
retail.shape
# Out:
# (58, 6)

# %%
df1 = retail.dropna(how='all',inplace=True)

# %%
retail.isnull().sum()
# Out:
# Product Name       1
# Category           7
# storeManager       0
# quantity          25
# Price              5
# PercentageSold    13
# dtype: int64

# %%
retail.shape
# Out:
# (98, 6)
