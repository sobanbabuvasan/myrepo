# %%
print("Om Mahaa Ganapataye Namah")
# Out:
# Om Mahaa Ganapataye Namah

# %%
import pandas as pd

# %%
pd_series = pd.Series([5,7,8.2,0])
pd_series
# Out:
# 0    5.0
# 1    7.0
# 2    8.2
# 3    0.0
# dtype: float64

# %%
pd_series  = pd.Series([5,7,8.2,0], index = ['i','j','k','l'])
pd_series
# Out:
# i    5.0
# j    7.0
# k    8.2
# l    0.0
# dtype: float64

# %%
pd_series[0]
# Out:
# 5.0

# %%
pd_series['j']
# Out:
# 7.0

# %%
pd_series[pd_series < 4]
# Out:
# l    0.0
# dtype: float64

# %%
pd_series[pd_series > 0 ]
# Out:
# i    5.0
# j    7.0
# k    8.2
# dtype: float64

# %%
45.2/2.5
# Out:
# 18.080000000000002

# %%
x = [10,23,5]
y = [2,1,5]
print type(x)
print type(y)
print x; print y
# Out:
# <type 'list'>
# <type 'list'>
# [10, 23, 5]
# [2, 1, 5]

# %%
print x[0]
print y[0]
x[0] * y[0]
# Out:
# 10
# 2
# 20
